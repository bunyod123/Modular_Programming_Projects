# %%
import pandas as pd
import sys
from tabulate import tabulate
sys.path.append(r"C:\Users\bunyo\oneDrive\desktop\AI_Course\ModularProgramProjects\FourthWeekProject")

# %% [markdown]
# # jadvalni chaqiramiz

# %%
from scripts.model_training import jadval
print(jadval)
# Out:
#                Model  CV R2 (avg)  Test R2  Test MAE
# 0  Linear Regression         0.90     0.90      4.45
# 1              Ridge         0.89     0.89      4.47
# 2              Lasso         0.89     0.89      4.58
# 7  Gradient Boosting         0.89     0.89      4.65
# 4      Random Forest         0.88     0.88      4.85
# 5            XGBoost         0.86     0.87      5.00
# 3      Decision Tree         0.74     0.76      6.47
# 6                KNN         0.46     0.52     10.04

# %%
table = tabulate(jadval, headers='keys', tablefmt='fancy_grid')
print(table)
# Out:
# ╒════╤═══════════════════╤═══════════════╤═══════════╤════════════╕
# │    │ Model             │   CV R2 (avg) │   Test R2 │   Test MAE │
# ╞════╪═══════════════════╪═══════════════╪═══════════╪════════════╡
# │  0 │ Linear Regression │          0.9  │      0.9  │       4.45 │
# ├────┼───────────────────┼───────────────┼───────────┼────────────┤
# │  1 │ Ridge             │          0.89 │      0.89 │       4.47 │
# ├────┼───────────────────┼───────────────┼───────────┼────────────┤
# │  2 │ Lasso             │          0.89 │      0.89 │       4.58 │
# ├────┼───────────────────┼───────────────┼───────────┼────────────┤
# │  7 │ Gradient Boosting │          0.89 │      0.89 │       4.65 │
# ├────┼───────────────────┼───────────────┼───────────┼────────────┤
# │  4 │ Random Forest     │          0.88 │      0.88 │       4.85 │
# ├────┼───────────────────┼───────────────┼───────────┼────────────┤
# │  5 │ XGBoost           │          0.86 │      0.87 │       5    │
# ├────┼───────────────────┼───────────────┼───────────┼────────────┤
# │  3 │ Decision Tree     │          0.74 │      0.76 │       6.47 │
# ├────┼───────────────────┼───────────────┼───────────┼────────────┤
# │  6 │ KNN               │          0.46 │      0.52 │      10.04 │
# ╘════╧═══════════════════╧═══════════════╧═══════════╧════════════╛

# %% [markdown]
# # jadvalni saqlaymiz

# %%
with open("jadval.csv", "w", encoding="utf-8") as f:
    f.write(table)
