# %%
import pandas as pd
import sys
from tabulate import tabulate
sys.path.append(r"C:\Users\bunyo\OneDrive\Desktop\AI_Course\ModularProgramProjects\first_week_project")

# %% [markdown]
# # jadvalni chaqiramiz

# %%
from scripts.model_training import jadval
print(jadval)
# Out:
#                Model  CV R2 (avg)  accuracy
# 2      Decision Tree         1.00  1.000000
# 6  Gradient Boosting         1.00  1.000000
# 3      Random Forest         1.00  1.000000
# 4            XGBoost         1.00  0.994275
# 0                OvO         0.95  0.954198
# 5                KNN         0.95  0.952290
# 1                OvR         0.81  0.797710
# Eng zo'r model: OvR (accuracy: 0.7977099236641222)
# Eng zo'r model: OvR (accuracy: 0.7977099236641222)
#                Model  CV R2 (avg)  accuracy
# 2      Decision Tree         1.00  1.000000
# 6  Gradient Boosting         1.00  1.000000
# 3      Random Forest         1.00  1.000000
# 4            XGBoost         1.00  0.994275
# 0                OvO         0.95  0.954198
# 5                KNN         0.95  0.952290
# 1                OvR         0.81  0.797710

# %%
table = tabulate(jadval, headers='keys', tablefmt='fancy_grid')
print(table)
# Out:
# ╒════╤═══════════════════╤═══════════════╤════════════╕
# │    │ Model             │   CV R2 (avg) │   accuracy │
# ╞════╪═══════════════════╪═══════════════╪════════════╡
# │  2 │ Decision Tree     │          1    │   1        │
# ├────┼───────────────────┼───────────────┼────────────┤
# │  6 │ Gradient Boosting │          1    │   1        │
# ├────┼───────────────────┼───────────────┼────────────┤
# │  3 │ Random Forest     │          1    │   1        │
# ├────┼───────────────────┼───────────────┼────────────┤
# │  4 │ XGBoost           │          1    │   0.994275 │
# ├────┼───────────────────┼───────────────┼────────────┤
# │  0 │ OvO               │          0.95 │   0.954198 │
# ├────┼───────────────────┼───────────────┼────────────┤
# │  5 │ KNN               │          0.95 │   0.95229  │
# ├────┼───────────────────┼───────────────┼────────────┤
# │  1 │ OvR               │          0.81 │   0.79771  │
# ╘════╧═══════════════════╧═══════════════╧════════════╛

# %% [markdown]
# # jadvalni saqlaymiz

# %%
with open("jadval.csv", "w", encoding="utf-8") as f:
    f.write(table)
