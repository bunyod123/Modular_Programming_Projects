# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder,OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score,root_mean_squared_error
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\bunyo\OneDrive\Desktop\AI_Course\ModularProgramProjects\first_week_project\data_sampling\over_sampled_final_data.csv")
df.head()
# Out:
#        Rank     Score  Acedemik Reputation  Students  Citations_per_faculty  \
# 0  0.154430  0.440252             0.458586  0.856566               0.448485
# 1  0.865823  0.129560             0.084848  0.682828               0.390909
# 2  0.916456  0.098113             0.254545  0.559596               0.079798
# 3  0.946835  0.080503             0.068687  0.558586               0.620202
# 4  0.541772  0.947170             0.998990  1.000000               0.807071
#
#    faculty_student_ratio  employer_reputation  employment_outcomes  \
# 0               0.724771             0.235294             0.706478
# 1               0.711519             0.064909             0.082996
# 2               0.407747             0.216024             0.281377
# 3               0.190622             0.017241             0.028340
# 4               0.946993             0.993915             0.891700
#
#    international_faculty_ratio  sustainability_score  \
# ...

# %% [markdown]
# # Dataset ni ajratish

# %%
x = df.drop("Score",axis=1)
y = df['Score']

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.18,random_state=89)

# %% [markdown]
# # dataset toliq preprocessed bolgani uchun directly model training qilindi

# %%
model = Pipeline([
    ('regressor', RandomForestRegressor(max_depth=5, random_state=99))
])

# %%
model.fit(x_train,y_train)
x_train_predict = model.predict(x_train)
y_test_pred = model.predict(x_test)
rmse = root_mean_squared_error(y_test,y_test_pred)

print(f"Train r2: {r2_score(y_train,x_train_predict)}")
print(f"Test r2: {r2_score(y_test,y_test_pred)}")
print(f"Test rmse: {rmse}")
# Out:
# Train r2: 0.9911385320301582
# Test r2: 0.9896176164421522
# Test rmse: 0.029264720876358553

# %%
x.iloc[524,2387]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 x.iloc[524,2387]
#
# File c:\Users\bunyo\OneDrive\Desktop\AI_Course\ModularProgramProjects\first_week_project\myEnv\Lib\site-packages\pandas\core\indexing.py:1199, in _LocationIndexer.__getitem__(self, key)
#    1197     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1198     if self._is_scalar_access(key):
# -> 1199         return self.obj._get_value(*key, takeable=self._takeable)
#    1200     return self._getitem_tuple(key)
#    1201 else:
#    1202     # we by definition only have the 0th axis
#
# File c:\Users\bunyo\OneDrive\Desktop\AI_Course\ModularProgramProjects\first_week_project\myEnv\Lib\site-packages\pandas\core\frame.py:4486, in DataFrame._get_value(self, index, col, takeable)
#    4467 """
#    4468 Quickly retrieve single value at passed column and index.
#    4469
# ...
