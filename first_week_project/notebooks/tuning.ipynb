# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV

# %%
url = r"C:\Users\bunyo\OneDrive\Desktop\AI_Course\FirstWeekProject\data\preprocessed_data\preprocessed_data.csv"
df = pd.read_csv(url)
df.head()
# Out:
#     WIND  IND      RAIN  IND.1     T.MAX  IND.2     T.MIN   T.MIN.G  Year  \
# 0  13.67  0.0  0.002985    0.0  0.356877   0.00  0.515254  0.443709   0.0
# 1  11.50  0.0  0.076119    0.0  0.271375   0.00  0.532203  0.513245   0.0
# 2  11.25  0.0  0.005970    0.0  0.208178   0.00  0.406780  0.460265   0.0
# 3   8.63  0.0  0.002985    0.0  0.211896   0.00  0.403390  0.370861   0.0
# 4  11.92  0.0  0.155224    0.0  0.271375   0.25  0.338983  0.228477   0.0
#
#    Month       Day     T_AVG  IS_RAINIY  IS_FROST
# 0    0.0  0.000000  0.439104        1.0       0.0
# 1    0.0  0.033333  0.320144        1.0       0.0
# 2    0.0  0.066667  0.392398        1.0       0.0
# 3    0.0  0.100000  0.400650        1.0       0.0
# 4    0.0  0.133333  0.544500        1.0       0.0

# %%
x = df.drop('WIND',axis=1)
y = df['WIND']

x_train, x_test, y_train, y_test = train_test_split(x,y,random_state=99,test_size=0.21)

# %% [markdown]
# # Manual

# %%
RF = RandomForestRegressor(max_depth=4,n_estimators=40)
RF.fit(x_train,y_train)

RF_pred = RF.predict(x_test)
accuracy = r2_score(y_test,RF_pred)
print(f": R2 SCORE: {accuracy}")
# Out:
# : R2 SCORE: 0.18400405612873605

# %% [markdown]
# # GRID SEARCH

# %%
#

parametr = {
    'n_estimators':[5, 100, 102, 150],
    'max_depth':[4, 7, 9, 12]
}

grid_search = GridSearchCV(RandomForestRegressor(), param_grid=parametr, cv=3)
grid_search.fit(x_train,y_train)

pred = grid_search.predict(x_test)
gr_accuracy = r2_score(y_test,pred)
print(f"Grid search r2 score: {gr_accuracy}")
# Out:
# Grid search r2 score: 0.2597131471459191

# %% [markdown]
# # Randomized Search

# %%
parametr = {
    'n_estimators':[5,15, 145, 102, 200],
    'max_depth':[4, 7, 9, 12,15]
}

Random_search = RandomizedSearchCV(RandomForestRegressor(), parametr,random_state=99, cv=3,n_iter=7)
Random_search.fit(x_train,y_train)


print(f"Random search best parametrlari: {Random_search.best_params_}")

RF_r = RandomForestRegressor(**Random_search.best_params_)
RF_r.fit(x_train,y_train)

pred2 = RF_r.predict(x_test)
random_r2 = r2_score(y_test,pred2)

print(f"Eng yaxshi parametrlar: {Random_search.best_params_}")
print(f"Random search r2 score: {random_r2}")
# Out:
# Random search best parametrlari: {'n_estimators': 145, 'max_depth': 12}
# Eng yaxshi parametrlar: {'n_estimators': 145, 'max_depth': 12}
# Random search r2 score: 0.2611389639354368

# %% [markdown]
# # Bayesian optimization

# %%
# 
from skopt import BayesSearchCV

param = {
    "n_estimators":(60,100),
    "max_depth":(5,10)
}

bayes = BayesSearchCV(RandomForestRegressor(), param, cv=4,random_state=88,n_iter=5)
bayes.fit(x_train,y_train)

print(f"best parametrs: {bayes.best_params_}")

RF_b = RandomForestRegressor(**bayes.best_params_)
RF_b.fit(x_train,y_train)

pred3 = RF_b.predict(x_test)
bayes_r2 = r2_score(y_test,pred3)

print(f"Eng yaxshi parametrlar: {bayes.best_params_}")
print(f"Random search r2 score: {bayes_r2}")
# Out:
# best parametrs: OrderedDict({'max_depth': 9, 'n_estimators': 69})
# Eng yaxshi parametrlar: OrderedDict({'max_depth': 9, 'n_estimators': 69})
# Random search r2 score: 0.2501763192335005

# %% [markdown]
# # optuna

# %%
import optuna
from sklearn.model_selection import cross_val_score

def objective(trial):
  
    n_estimators = trial.suggest_int('n_estimators', 10, 200)
    max_depth = trial.suggest_int('max_depth', 2, 32, log=True)
    
    
    min_samples_split = trial.suggest_int('min_samples_split', 2, 20)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 20)
    
   
    model = RandomForestRegressor(
        n_estimators=n_estimators, 
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        random_state=42,
        n_jobs=-1 
    )
    
    
    score = cross_val_score(model, x, y, cv=6).mean()
    
    return score


study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=20)

print(f"Eng yaxshi parametrlar: {study.best_params}")
print(f"Eng yaxshi natija (R^2): {study.best_value}")
# Out:
# [I 2026-02-18 23:16:37,681] A new study created in memory with name: no-name-c26310e9-370f-44d1-b337-f301bc4e3f40
# [I 2026-02-18 23:16:38,512] Trial 0 finished with value: 0.14838322246694804 and parameters: {'n_estimators': 16, 'max_depth': 27, 'min_samples_split': 5, 'min_samples_leaf': 2}. Best is trial 0 with value: 0.14838322246694804.
# [I 2026-02-18 23:16:41,758] Trial 1 finished with value: 0.1948820628924014 and parameters: {'n_estimators': 164, 'max_depth': 16, 'min_samples_split': 16, 'min_samples_leaf': 10}. Best is trial 1 with value: 0.1948820628924014.
# [I 2026-02-18 23:16:43,876] Trial 2 finished with value: 0.1930156298784513 and parameters: {'n_estimators': 99, 'max_depth': 10, 'min_samples_split': 7, 'min_samples_leaf': 4}. Best is trial 1 with value: 0.1948820628924014.
# [I 2026-02-18 23:16:45,268] Trial 3 finished with value: 0.19329542016717713 and parameters: {'n_estimators': 68, 'max_depth': 9, 'min_samples_split': 12, 'min_samples_leaf': 4}. Best is trial 1 with value: 0.1948820628924014.
# [I 2026-02-18 23:16:47,928] Trial 4 finished with value: 0.19362716072553357 and parameters: {'n_estimators': 136, 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 18}. Best is trial 1 with value: 0.1948820628924014.
# [I 2026-02-18 23:16:50,064] Trial 5 finished with value: 0.1866700055456297 and parameters: {'n_estimators': 71, 'max_depth': 19, 'min_samples_split': 8, 'min_samples_leaf': 5}. Best is trial 1 with value: 0.1948820628924014.
# [I 2026-02-18 23:16:51,698] Trial 6 finished with value: 0.1930061636149835 and parameters: {'n_estimators': 59, 'max_depth': 12, 'min_samples_split': 11, 'min_samples_leaf': 11}. Best is trial 1 with value: 0.1948820628924014.
# [I 2026-02-18 23:16:55,882] Trial 7 finished with value: 0.19358878519087738 and parameters: {'n_estimators': 190, 'max_depth': 16, 'min_samples_split': 20, 'min_samples_leaf': 5}. Best is trial 1 with value: 0.1948820628924014.
# [I 2026-02-18 23:16:58,756] Trial 8 finished with value: 0.12591863730442104 and parameters: {'n_estimators': 196, 'max_depth': 2, 'min_samples_split': 15, 'min_samples_leaf': 10}. Best is trial 1 with value: 0.1948820628924014.
# [I 2026-02-18 23:17:01,536] Trial 9 finished with value: 0.16672172119222947 and parameters: {'n_estimators': 193, 'max_depth': 4, 'min_samples_split': 15, 'min_samples_leaf': 6}. Best is trial 1 with value: 0.1948820628924014.
# [I 2026-02-18 23:17:03,892] Trial 10 finished with value: 0.1813768020787515 and parameters: {'n_estimators': 147, 'max_depth': 5, 'min_samples_split': 20, 'min_samples_leaf': 17}. Best is trial 1 with value: 0.1948820628924014.
# [I 2026-02-18 23:17:06,907] Trial 11 finished with value: 0.19361622526675373 and parameters: {'n_estimators': 144, 'max_depth': 31, 'min_samples_split': 2, 'min_samples_leaf': 17}. Best is trial 1 with value: 0.1948820628924014.
# [I 2026-02-18 23:17:09,628] Trial 12 finished with value: 0.1926424164047437 and parameters: {'n_estimators': 146, 'max_depth': 18, 'min_samples_split': 16, 'min_samples_leaf': 20}. Best is trial 1 with value: 0.1948820628924014.
# [I 2026-02-18 23:17:11,722] Trial 13 finished with value: 0.19198585132352364 and parameters: {'n_estimators': 121, 'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 11}. Best is trial 1 with value: 0.1948820628924014.
# [I 2026-02-18 23:17:14,650] Trial 14 finished with value: 0.19425203128673493 and parameters: {'n_estimators': 156, 'max_depth': 22, 'min_samples_split': 13, 'min_samples_leaf': 14}. Best is trial 1 with value: 0.1948820628924014.
# [I 2026-02-18 23:17:17,817] Trial 15 finished with value: 0.19431220306751273 and parameters: {'n_estimators': 171, 'max_depth': 14, 'min_samples_split': 17, 'min_samples_leaf': 14}. Best is trial 1 with value: 0.1948820628924014.
# [I 2026-02-18 23:17:21,399] Trial 16 finished with value: 0.1939093936763229 and parameters: {'n_estimators': 173, 'max_depth': 14, 'min_samples_split': 18, 'min_samples_leaf': 8}. Best is trial 1 with value: 0.1948820628924014.
# [I 2026-02-18 23:17:24,126] Trial 17 finished with value: 0.1813462976378213 and parameters: {'n_estimators': 170, 'max_depth': 5, 'min_samples_split': 17, 'min_samples_leaf': 14}. Best is trial 1 with value: 0.1948820628924014.
# [I 2026-02-18 23:17:25,373] Trial 18 finished with value: 0.12706379676054355 and parameters: {'n_estimators': 103, 'max_depth': 2, 'min_samples_split': 18, 'min_samples_leaf': 13}. Best is trial 1 with value: 0.1948820628924014.
# [I 2026-02-18 23:17:27,834] Trial 19 finished with value: 0.19526473287185753 and parameters: {'n_estimators': 123, 'max_depth': 8, 'min_samples_split': 14, 'min_samples_leaf': 8}. Best is trial 19 with value: 0.19526473287185753.
# Eng yaxshi parametrlar: {'n_estimators': 123, 'max_depth': 8, 'min_samples_split': 14, 'min_samples_leaf': 8}
# Eng yaxshi natija (R^2): 0.19526473287185753
