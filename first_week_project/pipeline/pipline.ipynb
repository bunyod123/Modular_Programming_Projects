# %%
from sklearn.impute import SimpleImputer
import sys
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
sys.path.append(r"C:\Users\bunyo\oneDrive\desktop\AI_Course\ModularProgramProjects\FourthWeekProject")
from src.auto_pipline import Pipeline

# %%
path = r"C:\Users\bunyo\OneDrive\Desktop\AI_Course\ModularProgramProjects\FourthWeekProject\data\engineered_data\engineered_data.csv"
df = pd.read_csv(path)
df
# Out:
#      age  gender  study_hours_per_day  social_media_hours  netflix_hours  \
# 0     23  Female                  0.0                 1.2            1.1
# 1     20  Female                  6.9                 2.8            2.3
# 2     21    Male                  1.4                 3.1            1.3
# 3     23  Female                  1.0                 3.9            1.0
# 4     19  Female                  5.0                 4.4            0.5
# ..   ...     ...                  ...                 ...            ...
# 995   21  Female                  2.6                 0.5            1.6
# 996   17  Female                  2.9                 1.0            2.4
# 997   20    Male                  3.0                 2.6            1.3
# 998   24    Male                  5.4                 4.1            1.1
# 999   19  Female                  4.3                 2.9            1.9
#
#     part_time_job  attendance_percentage  sleep_hours diet_quality  \
# ...

# %%
pipeline = Pipeline(df=df, target="exam_score", model=RandomForestRegressor(n_estimators=99))
pipeline.prepare_feature().fit()
y_pred = pipeline.predict()
print("R2 Score:", pipeline.score())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 pipeline = Pipeline(df=df, target="exam_score", model=RandomForestRegressor(n_estimators=99))
# ----> 2 pipeline.prepare_feature().fit()
#       3 y_pred = pipeline.predict()
#       4 print("R2 Score:", pipeline.score())
#
# File ~\oneDrive\desktop\AI_Course\ModularProgramProjects\FourthWeekProject\src\auto_pipline.py:28, in Pipeline.prepare_feature(self)
#      26 X = self.df.drop(columns=[self.target])
#      27 y = self.df[self.target]
# ---> 28 logging.log("X va y fetures tayinlandi")
#      30 num_col = X.select_dtypes(include=[np.number]).columns.tolist()
#      31 cat_col = X.select_dtypes(exclude=[np.number]).columns.tolist()
#
# TypeError: Logger.log() missing 1 required positional argument: 'msg'
