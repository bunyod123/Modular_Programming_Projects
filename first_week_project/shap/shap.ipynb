# %%
import sys
import pandas as pd
import joblib
from tabulate import tabulate
from sklearn.datasets import make_regression

sys.path.append(r"C:\Users\bunyo\oneDrive\desktop\AI_Course\ModularProgramProjects\")


from shap_utils import ShapAnalyzer 
    
    print(f"Ma'lumotlar yuklandi: {X.shape}")

   
    trainer = ModelTrainer(X, y)
    results = trainer.train_all()

    best_model_name = results.iloc[0]["Model"]
    best_r2 = results.iloc[0]["Test R2"]

    
    best_model = trainer.trained_models[best_model_name]

    joblib.dump(best_model, "best_model.pkl")
