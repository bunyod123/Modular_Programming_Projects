# %%
import joblib
import pandas as pd

# %%
df2 = pd.read_csv(r"C:\Users\bunyo\onedrive\desktop\AI_Course\ModularProgramProjects\Second_week_project\offline_testing\data_for_offline_test\scraped_data\new_earthquake.csv")

# %%
df2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 189 entries, 0 to 188
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          189 non-null    str
#  1   Location      189 non-null    str
#  2   Lat_degrees   189 non-null    float64
#  3   Long_degrees  189 non-null    float64
#  4   Depth         189 non-null    int64
#  5   Type          189 non-null    str
#  6   Magnituda     188 non-null    float64
#  7   Network       189 non-null    str
# dtypes: float64(3), int64(1), str(4)
# memory usage: 11.9 KB

# %%
df = df2.drop(columns=["Magnituda"])

# %% [markdown]
# # test qilish

# %%
model_path = r"C:\Users\bunyo\onedrive\desktop\AI_Course\ModularProgramProjects\Second_week_project\offline_testing\pipline_model\earthquake_model.joblib"
loaded_pipeline = joblib.load(model_path)

new_data_cleaned = df.dropna()

predictions = loaded_pipeline.predict(new_data_cleaned)


new_data_cleaned['Predicted_Risk_Level'] = predictions

print(new_data_cleaned[['Lat_degrees', 'Long_degrees', 'Predicted_Risk_Level']].head(10))
# Out:
#    Lat_degrees  Long_degrees Predicted_Risk_Level
# 0       46.266         7.006              Xavfsiz
# 1      -21.240       -68.470              Xavfsiz
# 2       -2.430       101.910              Xavfsiz
# 3       35.628        32.365              Xavfsiz
# 4       35.757        32.312              Xavfsiz
# 5      -32.824       -71.935               Xavfli
# 6      -32.890       -72.350              Xavfsiz
# 7       -2.230       138.900               Xavfli
# 8       37.176        14.641              Xavfsiz
# 9       37.792        36.175              Xavfsiz

# %%
df2.head(10)
# Out:
#                     Date                     Location  Lat_degrees  \
# 0  2026-02-24 14:30:58.9                  SWITZERLAND       46.266
# 1  2026-02-24 14:29:06.0           ANTOFAGASTA, CHILE      -21.240
# 2  2026-02-24 14:22:47.0  SOUTHERN SUMATRA, INDONESIA       -2.430
# 3  2026-02-24 14:22:33.9                CYPRUS REGION       35.628
# 4  2026-02-24 14:22:32.0                CYPRUS REGION       35.757
# 5  2026-02-24 14:10:19.3   OFFSHORE VALPARAISO, CHILE      -32.824
# 6  2026-02-24 14:10:13.0   OFFSHORE VALPARAISO, CHILE      -32.890
# 7  2026-02-24 14:03:59.0             PAPUA, INDONESIA       -2.230
# 8  2026-02-24 13:56:19.4                SICILY, ITALY       37.176
# 9  2026-02-24 13:52:57.0               CENTRAL TURKEY       37.792
#
#    Long_degrees  Depth    Type  Magnituda Network
# 0         7.006      3  origin        1.5   ETHZ*
# 1       -68.470    140  origin        2.9    CSN*
# 2       101.910    124  origin        2.6   BMKG*
# ...
