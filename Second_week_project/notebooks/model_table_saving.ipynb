# %%
import pandas as pd
import sys
from tabulate import tabulate
sys.path.append(r"C:\Users\bunyo\OneDrive\Desktop\AI_Course\ModularProgramProjects\Second_week_project")

# %%
from scripts.model_trainig import jadval
# Out:
#                Model  CV ACC (avg)  accuracy
# 2      Decision Tree          1.00  1.000000
# 4            XGBoost          1.00  1.000000
# 3      Random Forest          1.00  1.000000
# 6  Gradient Boosting          1.00  1.000000
# 5                KNN          0.98  0.983957
# 0                OvO          0.97  0.981283
# 1                OvR          0.91  0.919404
# Eng zo'r model: Decision Tree (accuracy: 1.0)
# Eng yomon model: OvR (accuracy: 0.9194041252864782)

# %%
table = tabulate(jadval, headers='keys', tablefmt='fancy_grid')
print(table)
# Out:
# ╒════╤═══════════════════╤════════════════╤════════════╕
# │    │ Model             │   CV ACC (avg) │   accuracy │
# ╞════╪═══════════════════╪════════════════╪════════════╡
# │  2 │ Decision Tree     │           1    │   1        │
# ├────┼───────────────────┼────────────────┼────────────┤
# │  4 │ XGBoost           │           1    │   1        │
# ├────┼───────────────────┼────────────────┼────────────┤
# │  3 │ Random Forest     │           1    │   1        │
# ├────┼───────────────────┼────────────────┼────────────┤
# │  6 │ Gradient Boosting │           1    │   1        │
# ├────┼───────────────────┼────────────────┼────────────┤
# │  5 │ KNN               │           0.98 │   0.983957 │
# ├────┼───────────────────┼────────────────┼────────────┤
# │  0 │ OvO               │           0.97 │   0.981283 │
# ├────┼───────────────────┼────────────────┼────────────┤
# │  1 │ OvR               │           0.91 │   0.919404 │
# ...

# %%
import os
path = r"C:\Users\bunyo\onedrive\desktop\AI_Course\ModularProgramProjects\Second_week_project\models\table"
full_path = os.path.join(path, "jadval.csv")
with open(full_path, "w", encoding="utf-8") as f:
    f.write(table)
