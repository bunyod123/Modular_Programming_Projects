# %%
import pandas as pd
import sys
from tabulate import tabulate
sys.path.append(r"C:\Users\bunyo\OneDrive\Desktop\AI_Course\ModularProgramProjects\Second_week_project")

# %%
from scripts.model_trainig import jadval
print(jadval)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from scripts.model_trainig import jadval
#       2 print(jadval)
#
# File ~\OneDrive\Desktop\AI_Course\ModularProgramProjects\Second_week_project\scripts\model_trainig.py:11
#       7 sys.path.append(r"C:\Users\bunyo\OneDrive\Desktop\AI_Course\ModularProgramProjects\Second_week_project")
#       8 df = pd.read_csv(r"C:\Users\bunyo\onedrive\desktop\AI_Course\ModularProgramProjects\Second_week_project\data\sampled_final_data\sampled_final_data.csv")
# ---> 11 from source.model_trainig import ModelTraining
#      14 X = df.drop("Mag_Level", axis=1, errors='ignore')
#      15 y = df["Mag_Level"]
#
# File ~\OneDrive\Desktop\AI_Course\ModularProgramProjects\Second_week_project\source\__init__.py:3
#       1 from .log import get_logger
#       2 from .data_loading import data_loading
# ----> 3 from .model_trainig import ModelTraining
#       4 from .prerocessing import Prerocessing
#       5 from .engineering import feature_engineering
#
# File ~\OneDrive\Desktop\AI_Course\ModularProgramProjects\Second_week_project\source\model_trainig.py:17
#      15 from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
#      16 from sklearn.svm import SVC
# ---> 17 from xgboost import XGBClassifier
#      18 # from lightgbm import LGBMClassifier
#      19 # from sklearn.linear_model import Ridge, Lasso
#      20 from sklearn.neighbors import KNeighborsClassifier
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
table = tabulate(jadval, headers='keys', tablefmt='fancy_grid')
print(table)

# %%
with open("jadval.csv", "w", encoding="utf-8") as f:
    f.write(table)
