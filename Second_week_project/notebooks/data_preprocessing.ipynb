# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\bunyo\onedrive\desktop\AI_Course\ModularProgramProjects\Second_week_project\data\preprocessed_data\preprocessed_data.csv")

# %%
df
# Out:
#       Lat_degrees  Long_degrees     Depth  Magnituda  Is_Shallow  Mag_Level  \
# 0        0.515238      0.850344  0.045153   0.381579         1.0        0.5
# 1        0.467380      0.854178  0.560425   0.500000         0.0        0.0
# 2        0.735053      0.582645  0.026560   0.197368         1.0        0.5
# 3        0.479788      0.287870  0.173971   0.631579         0.0        0.0
# 4        0.480274      0.288059  0.152722   0.657895         0.0        1.0
# ...           ...           ...       ...        ...         ...        ...
# 9083     0.789113      0.520375  0.009296   0.157895         1.0        0.5
# 9084     0.726350      0.568514  0.046481   0.289474         1.0        0.5
# 9085     0.609394      0.237202  0.147410   0.513158         0.0        0.0
# 9086     0.497686      0.282739  0.219124   0.473684         0.0        0.0
# 9087     0.874906      0.112315  0.010624   0.276316         1.0        0.5
#
#       Type_mt  Type_origin
# 0         0.0          1.0
# 1         0.0          1.0
# 2         0.0          1.0
# 3         0.0          1.0
# 4         0.0          1.0
# ...       ...          ...
# 9083      0.0          1.0
# 9084      0.0          1.0
# 9085      0.0          1.0
# 9086      0.0          1.0
# 9087      0.0          1.0
#
# [9088 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9088 entries, 0 to 9087
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Lat_degrees   9088 non-null   float64
#  1   Long_degrees  9088 non-null   float64
#  2   Depth         9088 non-null   float64
#  3   Magnituda     9088 non-null   float64
#  4   Is_Shallow    9088 non-null   float64
#  5   Mag_Level     9088 non-null   float64
#  6   Type_mt       9088 non-null   float64
#  7   Type_origin   9088 non-null   float64
# dtypes: float64(8)
# memory usage: 568.1 KB
