# %%
import pandas as pd
import sys
from sklearn.model_selection import train_test_split
sys.path.append(r"C:\Users\bunyo\OneDrive\Desktop\AI_Course\ModularProgramProjects\finalProject")
from notebooks.voting import train_voting_model

# %%
df = pd.read_csv(r"C:\Users\bunyo\OneDrive\Desktop\AI_Course\ModularProgramProjects\finalProject\data\preprocessed_data\preprocessed_data.csv")

# %%
df.head()
# Out:
#    Range_km  Efficiency  Weight_kg  Acceleration(0-100)  Firth_stop_range_km  \
# 0  0.826772    0.370968   0.650771             0.142157             0.878080
# 1  0.637795    0.258065   0.454721             0.254902             0.660182
# 2  0.787402    0.193548   0.503854             0.230392             0.883268
# 3  0.433071    0.333333   0.345376             0.289216             0.435798
# 4  0.566929    0.139785   0.403661             0.205882             0.594034
#
#    Battery_kWh  Fast_charger(kW)  Towing_kg  Cargo_volume  Price/Range(km)  \
# 0     0.868203          0.696970   0.666667        0.2890         0.042895
# 1     0.576037          0.393939   0.533333        0.4760         0.024129
# 2     0.649770          0.630303   0.500000        0.2530         0.013405
# 3     0.435023          0.324242   0.166667        0.1815         0.028150
# 4     0.419355          0.333333   0.333333        0.3410         0.009383
#
# ...

# %% [markdown]
# # Regression Voting

# %%
x = df.drop(columns=['Range_km'])
y = df['Range_km']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=99)

# %%
train_voting_model(x_train,x_test,y_train,y_test,task_type='regression')
# Out:
# REGRESSION
# R2 Score: 0.9969
# MAE (Ortacha absolyut xato): 0.0063
# MSE (Ortacha kvadratik xato): 0.0001
# VotingRegressor(estimators=[('Random_Forest',
#                              RandomForestRegressor(random_state=42)),
#                             ('Gradient_Boosting',
#                              GradientBoostingRegressor(random_state=42)),
#                             ('Linear_Regression', LinearRegression())])

# %% [markdown]
# # Classification Voting

# %%
x = df.drop(columns=['Range_km_level'])
y = df['Range_km_level']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=99)

# %%
train_voting_model(x_train, x_test, y_train, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 train_voting_model(x_train, x_test, y_train, y_test)
#
# File ~\OneDrive\Desktop\AI_Course\ModularProgramProjects\finalProject\notebooks\voting.py:26, in train_voting_model(X_train, X_test, y_train, y_test, task_type)
#      15 lr_model = LogisticRegression(max_iter=1000, random_state=42)
#      17 model = VotingClassifier(
#      18     estimators=[
#      19         ('Random_Forest', rf_model),
#    (...)     23     voting='soft'
#      24 )
# ---> 26 model.fit(X_train, y_train)
#      27 y_pred = model.predict(X_test)
#      29 print("\nCLASSIFICATION")
#
# File c:\Users\bunyo\OneDrive\Desktop\AI_Course\ModularProgramProjects\finalProject\myEnv\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
# ...
