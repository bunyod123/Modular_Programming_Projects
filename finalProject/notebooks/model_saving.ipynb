# %%
import pandas as pd
import sys
from tabulate import tabulate
sys.path.append(r"C:\Users\bunyo\OneDrive\Desktop\AI_Course\ModularProgramProjects\finalProject")

# %%
baseline_df = pd.read_csv(r"C:\Users\bunyo\OneDrive\Desktop\AI_Course\ModularProgramProjects\finalProject\model\table\baseline_jadval.csv")
final_df = pd.read_csv(r"C:\Users\bunyo\OneDrive\Desktop\AI_Course\ModularProgramProjects\finalProject\model\table\final_jadval.csv")

# %%
from scripts.model_training import jadval
# Out:
#                  Model  CV ACC (avg)  Accuracy
# 1        Random Forest        0.9377    0.9280
# 7              XGBoost        0.9442    0.9258
# 6    Gradient Boosting        0.9447    0.9237
# 2          Extra Trees        0.9307    0.9237
# 0        Decision Tree        0.9107    0.9004
# 5            SVM (SVC)        0.9149    0.8898
# 3                  KNN        0.8786    0.8792
# 4  Logistic Regression        0.8842    0.8475
# Eng zo'r model: Random Forest (Accuracy: 0.928)
# Eng yomon model: Logistic Regression (Accuracy: 0.8475)

# %% [markdown]
# # After all process model accuracy

# %%
table = tabulate(jadval, headers='keys', tablefmt='fancy_grid')
print(table)

# %% [markdown]
# # Baseline model accuracy

# %%
print(baseline_df.to_markdown(index=False))
# Out:
# | Model               |   Price Accuracy (%) |   Range Accuracy (%) |   Average |
# |:--------------------|---------------------:|---------------------:|----------:|
# | XGBoost             |                88.16 |                96.05 |     92.11 |
# | Gradient Boosting   |                87.28 |                94.74 |     91.01 |
# | Extra Trees         |                86.84 |                93.42 |     90.13 |
# | Random Forest       |                86.4  |                93.42 |     89.91 |
# | SVM (SVC)           |                84.65 |                90.79 |     87.72 |
# | Decision Tree       |                83.33 |                92.11 |     87.72 |
# | KNN                 |                82.46 |                89.47 |     85.96 |
# | Logistic Regression |                79.39 |                86.4  |     82.89 |

# %% [markdown]
# # Final model accuracy

# %%
print(final_df.to_markdown(index=False))
# Out:
# | Model               |   Price Accuracy (%) |   Range Accuracy (%) |   Average |
# |:--------------------|---------------------:|---------------------:|----------:|
# | XGBoost             |                 97.2 |                 94   |      95.6 |
# | Gradient Boosting   |                 96   |                 92.4 |      94.2 |
# | Random Forest       |                 96.4 |                 90.8 |      93.6 |
# | Extra Trees         |                 96   |                 90.4 |      93.2 |
# | SVM (SVC)           |                 95.6 |                 84   |      89.8 |
# | Decision Tree       |                 92.8 |                 84.8 |      88.8 |
# | KNN                 |                 93.2 |                 84   |      88.6 |
# | Logistic Regression |                 91.2 |                 80.8 |      86   |

# %%
import os
path = r"C:\Users\bunyo\OneDrive\Desktop\AI_Course\ModularProgramProjects\finalProject\model\table"
full_path = os.path.join(path, "final_jadval.csv")
with open(full_path, "w", encoding="utf-8") as f:
    f.write(table)
