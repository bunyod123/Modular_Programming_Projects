# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OrdinalEncoder

# %%
df = pd.read_csv(r"C:\Users\bunyo\OneDrive\Desktop\AI_Course\ModularProgramProjects\finalProject\data\engineered_data\engineered_data.csv")

# %%
df
# Out:
#       Range_km  Efficiency  Weight_kg  Acceleration(0-100)  \
# 0          610         178       2360                  4.9
# 1          490         157       1953                  7.2
# 2          585         145       2055                  6.7
# 3          360         171       1726                  7.9
# 4          445         135       1847                  6.2
# ...        ...         ...        ...                  ...
# 1195       325         209       1955                  9.6
# 1196       265         260       2131                 13.1
# 1197       265         260       2161                 13.1
# 1198       185         250       1969                 12.1
# 1199       180         257       1989                 12.1
#
#       Firth_stop_range_km  Battery_kWh  Fast_charger(kW)  Towing_kg  \
# 0                     742        108.7               230       2000
# 1                     574         77.0               130       1600
# ...

# %%
cat_cols = df.select_dtypes(exclude=[np.number]).columns.tolist()

# %%
mapping = {'Price_level2' : ['cheap','affordable','expensive']}
mapping1 = {'Range_level2' : ['short','middle','long']}

# %%
encoder = OrdinalEncoder(categories=[['cheap','affordable','expensive']], 
                         handle_unknown='use_encoded_value', 
                         unknown_value=-1,
                         dtype=int
                         )

df[['Price_level']] =encoder.fit_transform(df[['Price_level']])

# %%
encoder = OrdinalEncoder(categories=[['short','middle','long']], 
                         handle_unknown='use_encoded_value', 
                         unknown_value=-1,
                         dtype=int
                         )

df[['Range_km_level']] =encoder.fit_transform(df[['Range_km_level']])

# %%
df
# Out:
#       Range_km  Efficiency  Weight_kg  Acceleration(0-100)  \
# 0          610         178       2360                  4.9
# 1          490         157       1953                  7.2
# 2          585         145       2055                  6.7
# 3          360         171       1726                  7.9
# 4          445         135       1847                  6.2
# ...        ...         ...        ...                  ...
# 1195       325         209       1955                  9.6
# 1196       265         260       2131                 13.1
# 1197       265         260       2161                 13.1
# 1198       185         250       1969                 12.1
# 1199       180         257       1989                 12.1
#
#       Firth_stop_range_km  Battery_kWh  Fast_charger(kW)  Towing_kg  \
# 0                     742        108.7               230       2000
# 1                     574         77.0               130       1600
# ...

# %%
df.corrwith(df['Price_level']).sort_values(ascending=False)
# Out:
# Price_level            1.000000
# Weight_kg              0.817119
# Battery_kWh            0.772543
# Price_Euro             0.739348
# Range_km               0.609682
# Fast_charger(kW)       0.602382
# Firth_stop_range_km    0.593894
# Range_km_level         0.587288
# Energy_weight_ratio    0.546860
# Price/Range(km)        0.499963
# Efficiency             0.407342
# Towing_kg              0.402578
# Added_Range_1Stop      0.378775
# Cargo_volume           0.259455
# FastCharge_time_hrs   -0.117509
# Acceleration(0-100)   -0.576027
# dtype: float64

# %%
num_cols = df.select_dtypes(include=[np.number]).columns.tolist()

# %%
to_remove = ['Range_km','Efficiency']

to_remove in num_cols
# Out:
# False

# %%
num_cols = df.select_dtypes(include=[np.number]).columns.tolist()
to_remove = ['Range_km','Efficiency']

if to_remove in num_cols:
    num_cols = [col for col in num_cols if col not in to_remove]
num_cols

# %%
num_cols

# %%
df = pd.read_csv(r"C:\Users\bunyo\OneDrive\Desktop\AI_Course\ModularProgramProjects\finalProject\data\preprocessed_data\preprocessed_data.csv")

# %%
df
# Out:
#       Range_km  Efficiency  Weight_kg  Acceleration(0-100)  \
# 0     0.826772    0.370968   0.650771             0.142157
# 1     0.637795    0.258065   0.454721             0.254902
# 2     0.787402    0.193548   0.503854             0.230392
# 3     0.433071    0.333333   0.345376             0.289216
# 4     0.566929    0.139785   0.403661             0.205882
# ...        ...         ...        ...                  ...
# 1195  0.377953    0.537634   0.455684             0.372549
# 1196  0.283465    0.811828   0.540462             0.544118
# 1197  0.283465    0.811828   0.554913             0.544118
# 1198  0.157480    0.758065   0.462428             0.495098
# 1199  0.149606    0.795699   0.472062             0.495098
#
#       Firth_stop_range_km  Battery_kWh  Fast_charger(kW)  Towing_kg  \
# 0                0.878080     0.868203          0.696970   0.666667
# 1                0.660182     0.576037          0.393939   0.533333
# ...
