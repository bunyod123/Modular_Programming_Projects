# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\bunyo\OneDrive\Desktop\AI_Course\ModularProgramProjects\finalProject\data\scraped_raw_data\car_data.csv")

# %%
df.sample(4)
# Out:
#                       Name Range_km Efficiency  Weight  Acceleration(0-100)  \
# 245        BMW iX xDrive45   470 km  202 Wh/km    2525                  5.1
# 760   Porsche Taycan Turbo   415 km  202 Wh/km    2380                  3.2
# 412  Mercedes-Benz EQE 300   525 km  170 Wh/km    2375                  6.9
# 438        Skoda Enyaq 85x   455 km  169 Wh/km    2186                  6.7
#
#      Firth_stop_range  Battery_kWh  Fast_charger(kW)  Towing_kg  Cargo_volume  \
# 245               490         94.8               115       2500           500
# 760               518         83.7               200          0           450
# 412               570         89.0               120        750           430
# 438               501         77.0               120       1800           585
#
#      Price/Range(km)     Price
# 245              182   €83,500
# 760              367  €156,348
# 412              128   €67,187
# 438              113   €51,500

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 1200 non-null   str
#  1   Range_km             1200 non-null   str
#  2   Efficiency           1200 non-null   str
#  3   Weight               1200 non-null   int64
#  4   Acceleration(0-100)  1200 non-null   float64
#  5   Firth_stop_range     1200 non-null   int64
#  6   Battery_kWh          1200 non-null   float64
#  7   Fast_charger(kW)     1200 non-null   int64
#  8   Towing_kg            1200 non-null   int64
#  9   Cargo_volume         1200 non-null   int64
#  10  Price/Range(km)      1200 non-null   int64
#  11  Price                1110 non-null   str
# dtypes: float64(2), int64(6), str(4)
# memory usage: 112.6 KB

# %%
cols = ['Range_km','Efficiency','Price']

df[cols] = df[cols].replace(r"[^ 0-9 , .]", '', regex=True)

df[['Range_km','Efficiency']] = df[['Range_km','Efficiency']].astype(int)
df['Price'] = df['Price'].str.replace(',','.').astype(float)

df = df.rename(columns={'Weight':'Weight_kg', 'Firth_stop_range':'Firth_stop_range_km','Price':'Price_Euro'})

# %%
df.head()
# Out:
#                            Name  Range_km  Efficiency  Weight_kg  \
# 0             BMW iX3 50 xDrive       610         178       2360
# 1  Tesla Model Y Long Range RWD       490         157       1953
# 2        Mercedes-Benz CLA 250+       585         145       2055
# 3        MG MG4 Electric 64 kWh       360         171       1726
# 4             Tesla Model 3 RWD       445         135       1847
#
#    Acceleration(0-100)  Firth_stop_range_km  Battery_kWh  Fast_charger(kW)  \
# 0                  4.9                  742        108.7               230
# 1                  7.2                  574         77.0               130
# 2                  6.7                  746         85.0               208
# 3                  7.9                  401         61.7               107
# 4                  6.2                  523         60.0               110
#
#    Towing_kg  Cargo_volume  Price/Range(km)  Price_Euro
# 0       2000           578              114      70.900
# 1       1600           952              100      47.970
# 2       1500           506               92      55.728
# 3        500           363              103      39.990
# 4       1000           682               89      37.970

# %%
df1 = df[df['Price_Euro'].isnull()]

df1['Price_Euro'] = (df1['Range_km'] * df1['Price/Range(km)']) / 1000

# %%
# Out:
# 123433.212

# %%
df1
# Out:
#                                   Name  Range_km  Efficiency  Weight_kg  \
# 16           BYD ATTO 3 Evo RWD Design       415         180       1880
# 35                         Jaecoo 5 EV       325         181       1765
# 68    Toyota bZ4X Touring AWD 74.7 kWh       385         184       2075
# 95                            Omoda E5       330         178       1785
# 96                     Mazda 6e 78 kWh       470         164       2090
# ...                                ...       ...         ...        ...
# 1138       Skywell BE11 Standard Range       325         209       1955
# 1149    Toyota Proace Shuttle M 75 kWh       265         260       2131
# 1169    Toyota Proace Shuttle L 75 kWh       265         260       2161
# 1189    Toyota Proace Shuttle M 50 kWh       185         250       1969
# 1199    Toyota Proace Shuttle L 50 kWh       180         257       1989
#
#       Acceleration(0-100)  Firth_stop_range_km  Battery_kWh  Fast_charger(kW)  \
# 16                    5.5                  472         74.8               130
# 35                    7.7                  341         58.9                80
# 68                    4.4                  419         71.0               110
# 95                    7.6                  350         58.9                80
# 96                    7.9                  545         77.0               135
# ...                   ...                  ...          ...               ...
# 1138                  9.6                  296         68.0                50
# 1149                 13.1                  252         69.0                77
# 1169                 13.1                  252         69.0                77
# 1189                 12.1                  196         46.3                74
# 1199                 12.1                  189         46.3                74
#
#       Towing_kg  Cargo_volume  Price/Range(km)  Price_Euro
# 16         1500           591              111      46.065
# 35         1250           480               96      31.200
# 68         1500           600              138      53.130
# 95            0           380              103      33.990
# 96         1500           528               95      44.650
# ...         ...           ...              ...         ...
# 1138          0           467              131      42.575
# 1149       1000           550              227      60.155
# 1169       1000           980              263      69.695
# 1189       1000           550              318      58.830
# 1199       1000           980              381      68.580
#
# [90 rows x 12 columns]

# %%
df.head()
# Out:
#                            Name  Range_km  Efficiency  Weight_kg  \
# 0             BMW iX3 50 xDrive       610         178       2360
# 1  Tesla Model Y Long Range RWD       490         157       1953
# 2        Mercedes-Benz CLA 250+       585         145       2055
# 3        MG MG4 Electric 64 kWh       360         171       1726
# 4             Tesla Model 3 RWD       445         135       1847
#
#    Acceleration(0-100)  Firth_stop_range_km  Battery_kWh  Fast_charger(kW)  \
# 0                  4.9                  742        108.7               230
# 1                  7.2                  574         77.0               130
# 2                  6.7                  746         85.0               208
# 3                  7.9                  401         61.7               107
# 4                  6.2                  523         60.0               110
#
#    Towing_kg  Cargo_volume  Price/Range(km)  Price_Euro
# 0       2000           578              114      70.900
# 1       1600           952              100      47.970
# 2       1500           506               92      55.728
# 3        500           363              103      39.990
# 4       1000           682               89      37.970

# %%
df = df.dropna()

# %%
new_df = pd.concat([df, df1])

# %%
new_df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1200 entries, 0 to 1199
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 1200 non-null   str
#  1   Range_km             1200 non-null   int64
#  2   Efficiency           1200 non-null   int64
#  3   Weight_kg            1200 non-null   int64
#  4   Acceleration(0-100)  1200 non-null   float64
#  5   Firth_stop_range_km  1200 non-null   int64
#  6   Battery_kWh          1200 non-null   float64
#  7   Fast_charger(kW)     1200 non-null   int64
#  8   Towing_kg            1200 non-null   int64
#  9   Cargo_volume         1200 non-null   int64
#  10  Price/Range(km)      1200 non-null   int64
#  11  Price_Euro           1200 non-null   float64
# dtypes: float64(3), int64(8), str(1)
# memory usage: 121.9 KB

# %%
new_df.head()
# Out:
#                            Name  Range_km  Efficiency  Weight_kg  \
# 0             BMW iX3 50 xDrive       610         178       2360
# 1  Tesla Model Y Long Range RWD       490         157       1953
# 2        Mercedes-Benz CLA 250+       585         145       2055
# 3        MG MG4 Electric 64 kWh       360         171       1726
# 4             Tesla Model 3 RWD       445         135       1847
#
#    Acceleration(0-100)  Firth_stop_range_km  Battery_kWh  Fast_charger(kW)  \
# 0                  4.9                  742        108.7               230
# 1                  7.2                  574         77.0               130
# 2                  6.7                  746         85.0               208
# 3                  7.9                  401         61.7               107
# 4                  6.2                  523         60.0               110
#
#    Towing_kg  Cargo_volume  Price/Range(km)  Price_Euro
# 0       2000           578              114      70.900
# 1       1600           952              100      47.970
# 2       1500           506               92      55.728
# 3        500           363              103      39.990
# 4       1000           682               89      37.970

# %%
import os
path = r"C:\Users\bunyo\OneDrive\Desktop\AI_Course\ModularProgramProjects\finalProject\data\raw_data"

full_data_path = os.path.join(path,"cleaned_raw_data.csv")
new_df.to_csv(full_data_path, index = False)

# %%
new_df.corrwith(df['Price_Euro']).sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 new_df.corrwith(df['Price_Euro']).sort_values(ascending=False)
#
# File c:\Users\bunyo\OneDrive\Desktop\AI_Course\ModularProgramProjects\finalProject\myEnv\Lib\site-packages\pandas\core\frame.py:13374, in DataFrame.corrwith(self, other, axis, drop, method, numeric_only, min_periods)
#   13371 this = self._get_numeric_data() if numeric_only else self
#   13373 if isinstance(other, Series):
# > 13374     return this.apply(
#   13375         lambda x: other.corr(x, method=method, min_periods=min_periods),
#   13376         axis=axis,
#   13377     )
#   13379 if numeric_only:
#   13380     other = other._get_numeric_data()
#
# File c:\Users\bunyo\OneDrive\Desktop\AI_Course\ModularProgramProjects\finalProject\myEnv\Lib\site-packages\pandas\core\frame.py:12419, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   12405         raise ValueError(f"Unknown engine '{engine}'")
#   12407     op = frame_apply(
#   12408         self,
#   12409         func=func,
#    (...)  12417         kwargs=kwargs,
#   12418     )
# > 12419     return op.apply().__finalize__(self, method="apply")
#   12420 elif hasattr(engine, "__pandas_udf__"):
#   12421     if result_type is not None:
#
# File c:\Users\bunyo\OneDrive\Desktop\AI_Course\ModularProgramProjects\finalProject\myEnv\Lib\site-packages\pandas\core\apply.py:1015, in FrameApply.apply(self)
#    1012 elif self.raw:
#    1013     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# -> 1015 return self.apply_standard()
#
# File c:\Users\bunyo\OneDrive\Desktop\AI_Course\ModularProgramProjects\finalProject\myEnv\Lib\site-packages\pandas\core\apply.py:1167, in FrameApply.apply_standard(self)
#    1165 def apply_standard(self):
#    1166     if self.engine == "python":
# -> 1167         results, res_index = self.apply_series_generator()
#    1168     else:
#    1169         results, res_index = self.apply_series_numba()
#
# File c:\Users\bunyo\OneDrive\Desktop\AI_Course\ModularProgramProjects\finalProject\myEnv\Lib\site-packages\pandas\core\apply.py:1183, in FrameApply.apply_series_generator(self)
#    1180 results = {}
#    1182 for i, v in enumerate(series_gen):
# -> 1183     results[i] = self.func(v, *self.args, **self.kwargs)
#    1184     if isinstance(results[i], ABCSeries):
#    1185         # If we have a view on v, we need to make a copy because
#    1186         #  series_generator will swap out the underlying data
#    1187         results[i] = results[i].copy(deep=False)
#
# File c:\Users\bunyo\OneDrive\Desktop\AI_Course\ModularProgramProjects\finalProject\myEnv\Lib\site-packages\pandas\core\frame.py:13375, in DataFrame.corrwith.<locals>.<lambda>(x)
#   13371 this = self._get_numeric_data() if numeric_only else self
#   13373 if isinstance(other, Series):
#   13374     return this.apply(
# > 13375         lambda x: other.corr(x, method=method, min_periods=min_periods),
#   13376         axis=axis,
#   13377     )
#   13379 if numeric_only:
#   13380     other = other._get_numeric_data()
#
# File c:\Users\bunyo\OneDrive\Desktop\AI_Course\ModularProgramProjects\finalProject\myEnv\Lib\site-packages\pandas\core\series.py:2771, in Series.corr(self, other, method, min_periods)
#    2768     return np.nan
#    2770 this_values = this.to_numpy(dtype=float, na_value=np.nan, copy=False)
# -> 2771 other_values = other.to_numpy(dtype=float, na_value=np.nan, copy=False)
#    2773 if method in ["pearson", "spearman", "kendall"] or callable(method):
#    2774     result = nanops.nancorr(
#    2775         this_values, other_values, method=method, min_periods=min_periods
#    2776     )
#
# File c:\Users\bunyo\OneDrive\Desktop\AI_Course\ModularProgramProjects\finalProject\myEnv\Lib\site-packages\pandas\core\base.py:664, in IndexOpsMixin.to_numpy(self, dtype, copy, na_value, **kwargs)
#     574 """
#     575 A NumPy ndarray representing the values in this Series or Index.
#     576
#    (...)    661       dtype='datetime64[ns]')
#     662 """
#     663 if isinstance(self.dtype, ExtensionDtype):
# --> 664     return self.array.to_numpy(dtype, copy=copy, na_value=na_value, **kwargs)
#     665 elif kwargs:
#     666     bad_keys = next(iter(kwargs.keys()))
#
# File c:\Users\bunyo\OneDrive\Desktop\AI_Course\ModularProgramProjects\finalProject\myEnv\Lib\site-packages\pandas\core\arrays\numpy_.py:589, in NumpyExtensionArray.to_numpy(self, dtype, copy, na_value)
#     586         result = result.view()
#     587         result.flags.writeable = False
# --> 589 result = np.asarray(result, dtype=dtype)
#     591 if copy and result is self._ndarray:
#     592     result = result.copy()
#
# ValueError: could not convert string to float: 'BMW iX3 50 xDrive'
