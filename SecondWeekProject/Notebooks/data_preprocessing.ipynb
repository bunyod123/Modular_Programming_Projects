# %%
import sys
path = sys.path.append(r"C:\Users\bunyo\oneDrive\desktop\AI_Course\ModularProgramProjects\SecondWeekProject")


from src.logger import get_logger

logging = get_logger("preprocessing")

logging.info("preprocessing boshlandi va toxtadi")

# %%
import pandas as pd

# %%
import sys
import pandas as pd
sys.path.append(r"C:\Users\bunyo\oneDrive\desktop\AI_Course\ModularProgramProjects\SecondWeekProject")


data_link = r"C:\Users\bunyo\OneDrive\Desktop\AI_Course\ModularProgramProjects\SecondWeekProject\data\raw_data\train.csv"
df = pd.read_csv(data_link)
from src.data_preprocessing import Preprocessing
step = Preprocessing(df)

df1 = step.fillingNan().logTransformation().scaling()

print(df.head())
